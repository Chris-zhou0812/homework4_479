# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
flight = pd.read_csv("../data/raw/Air_Traffic_Passenger_Statistics.csv")

# %%
flight
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507       Air Canada                           AC
# 4               200507       Air Canada                           AC
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
flight.dtypes
#inspection
# Out:
# Activity Period                 int64
# Operating Airline              object
# Operating Airline IATA Code    object
# Published Airline              object
# Published Airline IATA Code    object
# GEO Summary                    object
# GEO Region                     object
# Activity Type Code             object
# Price Category Code            object
# Terminal                       object
# Boarding Area                  object
# Passenger Count                 int64
# Adjusted Activity Type Code    object
# Adjusted Passenger Count        int64
# Year                            int64
# Month                          object
# dtype: object

# %% [markdown]
# * calculate summary statistics for  passenger count in 2016

# %%
flight_2016 = flight[flight['Year'] == 2016]
flight_2016
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 12403           201603         Air China                          CA
# 14637           201601        Aer Lingus                          EI
# 14638           201601        Aer Lingus                          EI
# 14639           201601        Aeromexico                          AM
# 14640           201601        Aeromexico                          AM
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
flight_2016['Passenger Count'].describe()
# Out:
# count       371.000000
# mean      30808.212938
# std       56351.917740
# min           2.000000
# 25%        5609.500000
# 50%        8766.000000
# 75%       19856.500000
# max      327187.000000
# Name: Passenger Count, dtype: float64

# %% [markdown]
# We can see that mean values are 30808.212938, min is 2.000000
# 25%        5609.500000, max is 327187.000000, and 75% being 19856.500000

# %% [markdown]
# * visualization for the sum of passenger count from 2012 to 2016

# %%
flight_2012 = flight[flight['Year'] == 2012]
flight_2013= flight[flight['Year'] == 2013]
flight_2014 = flight[flight['Year'] == 2014]
flight_2015 = flight[flight['Year'] == 2015]
flight_2016 = flight[flight['Year'] == 2016]

# %%
# draw a bar plot
plt.bar( [2012, 2013, 2014, 2015, 2016], [flight_2012['Passenger Count'].sum(), flight_2013['Passenger Count'].sum(),flight_2014['Passenger Count'].sum(), flight_2015['Passenger Count'].sum(),flight_2016['Passenger Count'].sum()])
plt.xlabel("Year")
plt.ylabel("Sum of adjusted passenger count in this year")
plt.show()

# %% [markdown]
# Conclusion: we can see the 2016 value is way smaller

# %% [markdown]
# * doing a value count for Price Category code

# %%
# see there are only two unique values in the column
traffic['Price Category Code'].unique()
traffic['Price Category Code'].value_counts()
# Out:
# Other       13087
# Low Fare     1920
# Name: Price Category Code, dtype: int64

# %% [markdown]
# We see the values for other and low Fare are extremely disapproportionate, which renders our dataset to be biased upon other type.

# %% [markdown]
# * adding a new column

# %%
traffic['difference Passenger Count'] = traffic['Passenger Count'] - traffic[ 'Adjusted Passenger Count']
print(traffic.head())
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507       Air Canada                           AC
# 4           200507       Air Canada                           AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3       Air Canada                           AC  International     Canada
# 4       Air Canada                           AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# ...

# %% [markdown]
# Conclusion: we see most rows don't have difference between Passenger count and adjusted Passenger Count, which means most differences have already eliminated

# %% [markdown]
# Now we are finished with everyhting using at least four analysis!That's perfect.
